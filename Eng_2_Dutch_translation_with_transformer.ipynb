# %% [markdown]
# # English-to-Dutch translation with a sequence-to-sequence Transformer
#
# **Author:** [Disan](https://be.linkedin.com/in/disan-ssebowa-basalidde-2a89b61bb)<br>
#
# **Description:** Implementing a sequence-to-sequene Transformer and training it on a machine translation task.

# %% [markdown]
# ## Introduction
#
# - Vectorize text using the Keras `TextVectorization` layer.
# - Implement a `TransformerEncoder` layer, a `TransformerDecoder` layer,
# and a `PositionalEmbedding` layer.
# - Prepare data for training a sequence-to-sequence model.
# - Use the trained model to generate translations of never-seen-before
# input sentences (sequence-to-sequence inference).

# %% [markdown]
# ## Setup

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.

# %% [markdown]
# **Preprocessing data**

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open("/content/nld.txt", "r", encoding="utf-8") as f:
    lines = f.read().split("\n")
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split("\t")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0
# Out:
# Number of samples: 10000
# Number of unique input tokens: 70
# Number of unique output tokens: 76
# Max sequence length for inputs: 18
# Max sequence length for outputs: 54

# %%
# Define an input sequence and process it.
encoder_inputs = keras.Input(shape=(None, num_encoder_tokens))
encoder = keras.layers.LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = keras.layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Out:
# Epoch 1/100
# 125/125 [==============================] - 13s 44ms/step - loss: 1.2150 - accuracy: 0.7073 - val_loss: 1.1363 - val_accuracy: 0.6803
# Epoch 2/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.8633 - accuracy: 0.7672 - val_loss: 0.9029 - val_accuracy: 0.7473
# Epoch 3/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.7035 - accuracy: 0.8022 - val_loss: 0.7949 - val_accuracy: 0.7651
# Epoch 4/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.6188 - accuracy: 0.8196 - val_loss: 0.7197 - val_accuracy: 0.7885
# Epoch 5/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.5707 - accuracy: 0.8337 - val_loss: 0.6822 - val_accuracy: 0.8013
# Epoch 6/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.5634 - accuracy: 0.8384 - val_loss: 0.6583 - val_accuracy: 0.8065
# Epoch 7/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.5128 - accuracy: 0.8501 - val_loss: 0.6240 - val_accuracy: 0.8178
# Epoch 8/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.4883 - accuracy: 0.8577 - val_loss: 0.6011 - val_accuracy: 0.8243
# Epoch 9/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.4668 - accuracy: 0.8629 - val_loss: 0.5973 - val_accuracy: 0.8260
# Epoch 10/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.4474 - accuracy: 0.8688 - val_loss: 0.5682 - val_accuracy: 0.8342
# Epoch 11/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.4299 - accuracy: 0.8733 - val_loss: 0.5488 - val_accuracy: 0.8396
# Epoch 12/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.4138 - accuracy: 0.8787 - val_loss: 0.5499 - val_accuracy: 0.8380
# Epoch 13/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.3987 - accuracy: 0.8826 - val_loss: 0.5331 - val_accuracy: 0.8440
# Epoch 14/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.3849 - accuracy: 0.8868 - val_loss: 0.5200 - val_accuracy: 0.8479
# Epoch 15/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.3713 - accuracy: 0.8904 - val_loss: 0.5141 - val_accuracy: 0.8491
# Epoch 16/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.3590 - accuracy: 0.8939 - val_loss: 0.5071 - val_accuracy: 0.8514
# Epoch 17/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.3468 - accuracy: 0.8976 - val_loss: 0.5059 - val_accuracy: 0.8521
# Epoch 18/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.3355 - accuracy: 0.9014 - val_loss: 0.4983 - val_accuracy: 0.8559
# Epoch 19/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.3244 - accuracy: 0.9043 - val_loss: 0.4949 - val_accuracy: 0.8563
# Epoch 20/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.3144 - accuracy: 0.9075 - val_loss: 0.4917 - val_accuracy: 0.8576
# Epoch 21/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.3041 - accuracy: 0.9103 - val_loss: 0.4913 - val_accuracy: 0.8589
# Epoch 22/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.2949 - accuracy: 0.9136 - val_loss: 0.4905 - val_accuracy: 0.8603
# Epoch 23/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.2855 - accuracy: 0.9161 - val_loss: 0.4905 - val_accuracy: 0.8601
# Epoch 24/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.2766 - accuracy: 0.9189 - val_loss: 0.4879 - val_accuracy: 0.8616
# Epoch 25/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.2677 - accuracy: 0.9213 - val_loss: 0.4920 - val_accuracy: 0.8609
# Epoch 26/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.2598 - accuracy: 0.9238 - val_loss: 0.4894 - val_accuracy: 0.8621
# Epoch 27/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.2520 - accuracy: 0.9262 - val_loss: 0.4934 - val_accuracy: 0.8620
# Epoch 28/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.2439 - accuracy: 0.9286 - val_loss: 0.4910 - val_accuracy: 0.8636
# Epoch 29/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.2365 - accuracy: 0.9304 - val_loss: 0.4954 - val_accuracy: 0.8619
# Epoch 30/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.2297 - accuracy: 0.9326 - val_loss: 0.4989 - val_accuracy: 0.8633
# Epoch 31/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.2223 - accuracy: 0.9348 - val_loss: 0.5018 - val_accuracy: 0.8640
# Epoch 32/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.2157 - accuracy: 0.9364 - val_loss: 0.5067 - val_accuracy: 0.8627
# Epoch 33/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.2093 - accuracy: 0.9387 - val_loss: 0.5120 - val_accuracy: 0.8635
# Epoch 34/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.2031 - accuracy: 0.9405 - val_loss: 0.5169 - val_accuracy: 0.8626
# Epoch 35/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1971 - accuracy: 0.9422 - val_loss: 0.5166 - val_accuracy: 0.8631
# Epoch 36/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1911 - accuracy: 0.9439 - val_loss: 0.5194 - val_accuracy: 0.8634
# Epoch 37/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.1855 - accuracy: 0.9459 - val_loss: 0.5279 - val_accuracy: 0.8633
# Epoch 38/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.1800 - accuracy: 0.9475 - val_loss: 0.5312 - val_accuracy: 0.8628
# Epoch 39/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1746 - accuracy: 0.9487 - val_loss: 0.5331 - val_accuracy: 0.8629
# Epoch 40/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1698 - accuracy: 0.9503 - val_loss: 0.5405 - val_accuracy: 0.8632
# Epoch 41/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1642 - accuracy: 0.9522 - val_loss: 0.5524 - val_accuracy: 0.8626
# Epoch 42/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1604 - accuracy: 0.9531 - val_loss: 0.5493 - val_accuracy: 0.8633
# Epoch 43/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1559 - accuracy: 0.9545 - val_loss: 0.5611 - val_accuracy: 0.8615
# Epoch 44/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1509 - accuracy: 0.9559 - val_loss: 0.5658 - val_accuracy: 0.8617
# Epoch 45/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1471 - accuracy: 0.9570 - val_loss: 0.5644 - val_accuracy: 0.8629
# Epoch 46/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1430 - accuracy: 0.9581 - val_loss: 0.5734 - val_accuracy: 0.8623
# Epoch 47/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1388 - accuracy: 0.9596 - val_loss: 0.5877 - val_accuracy: 0.8619
# Epoch 48/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1350 - accuracy: 0.9606 - val_loss: 0.5886 - val_accuracy: 0.8629
# Epoch 49/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1315 - accuracy: 0.9617 - val_loss: 0.5929 - val_accuracy: 0.8619
# Epoch 50/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1278 - accuracy: 0.9625 - val_loss: 0.6014 - val_accuracy: 0.8618
# Epoch 51/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1246 - accuracy: 0.9636 - val_loss: 0.6055 - val_accuracy: 0.8616
# Epoch 52/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1208 - accuracy: 0.9650 - val_loss: 0.6086 - val_accuracy: 0.8609
# Epoch 53/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1178 - accuracy: 0.9655 - val_loss: 0.6185 - val_accuracy: 0.8612
# Epoch 54/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1149 - accuracy: 0.9665 - val_loss: 0.6218 - val_accuracy: 0.8612
# Epoch 55/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1120 - accuracy: 0.9672 - val_loss: 0.6331 - val_accuracy: 0.8619
# Epoch 56/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1092 - accuracy: 0.9680 - val_loss: 0.6310 - val_accuracy: 0.8608
# Epoch 57/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1062 - accuracy: 0.9688 - val_loss: 0.6443 - val_accuracy: 0.8610
# Epoch 58/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1033 - accuracy: 0.9698 - val_loss: 0.6458 - val_accuracy: 0.8607
# Epoch 59/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.1010 - accuracy: 0.9703 - val_loss: 0.6517 - val_accuracy: 0.8612
# Epoch 60/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.0987 - accuracy: 0.9712 - val_loss: 0.6634 - val_accuracy: 0.8603
# Epoch 61/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.0958 - accuracy: 0.9719 - val_loss: 0.6650 - val_accuracy: 0.8613
# Epoch 62/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0939 - accuracy: 0.9724 - val_loss: 0.6715 - val_accuracy: 0.8600
# Epoch 63/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.0916 - accuracy: 0.9730 - val_loss: 0.6685 - val_accuracy: 0.8620
# Epoch 64/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0896 - accuracy: 0.9737 - val_loss: 0.6863 - val_accuracy: 0.8600
# Epoch 65/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.0872 - accuracy: 0.9743 - val_loss: 0.6892 - val_accuracy: 0.8602
# Epoch 66/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.0849 - accuracy: 0.9750 - val_loss: 0.6908 - val_accuracy: 0.8607
# Epoch 67/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0834 - accuracy: 0.9753 - val_loss: 0.7058 - val_accuracy: 0.8586
# Epoch 68/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0814 - accuracy: 0.9760 - val_loss: 0.7043 - val_accuracy: 0.8597
# Epoch 69/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0796 - accuracy: 0.9766 - val_loss: 0.7090 - val_accuracy: 0.8595
# Epoch 70/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0779 - accuracy: 0.9769 - val_loss: 0.7163 - val_accuracy: 0.8592
# Epoch 71/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0759 - accuracy: 0.9776 - val_loss: 0.7257 - val_accuracy: 0.8586
# Epoch 72/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0742 - accuracy: 0.9780 - val_loss: 0.7345 - val_accuracy: 0.8595
# Epoch 73/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0726 - accuracy: 0.9784 - val_loss: 0.7372 - val_accuracy: 0.8589
# Epoch 74/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0713 - accuracy: 0.9788 - val_loss: 0.7371 - val_accuracy: 0.8598
# Epoch 75/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.0701 - accuracy: 0.9791 - val_loss: 0.7446 - val_accuracy: 0.8602
# Epoch 76/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0676 - accuracy: 0.9801 - val_loss: 0.7527 - val_accuracy: 0.8588
# Epoch 77/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0667 - accuracy: 0.9801 - val_loss: 0.7581 - val_accuracy: 0.8579
# Epoch 78/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0652 - accuracy: 0.9805 - val_loss: 0.7697 - val_accuracy: 0.8576
# Epoch 79/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0641 - accuracy: 0.9808 - val_loss: 0.7704 - val_accuracy: 0.8584
# Epoch 80/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0626 - accuracy: 0.9813 - val_loss: 0.7716 - val_accuracy: 0.8587
# Epoch 81/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.0611 - accuracy: 0.9819 - val_loss: 0.7792 - val_accuracy: 0.8585
# Epoch 82/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.0599 - accuracy: 0.9822 - val_loss: 0.7849 - val_accuracy: 0.8575
# Epoch 83/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0591 - accuracy: 0.9825 - val_loss: 0.7895 - val_accuracy: 0.8577
# Epoch 84/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0578 - accuracy: 0.9827 - val_loss: 0.7952 - val_accuracy: 0.8569
# Epoch 85/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0565 - accuracy: 0.9830 - val_loss: 0.8064 - val_accuracy: 0.8582
# Epoch 86/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0549 - accuracy: 0.9835 - val_loss: 0.8030 - val_accuracy: 0.8588
# Epoch 87/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0544 - accuracy: 0.9836 - val_loss: 0.8070 - val_accuracy: 0.8574
# Epoch 88/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.0533 - accuracy: 0.9839 - val_loss: 0.8220 - val_accuracy: 0.8565
# Epoch 89/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0521 - accuracy: 0.9842 - val_loss: 0.8237 - val_accuracy: 0.8568
# Epoch 90/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.0508 - accuracy: 0.9847 - val_loss: 0.8193 - val_accuracy: 0.8581
# Epoch 91/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0504 - accuracy: 0.9847 - val_loss: 0.8334 - val_accuracy: 0.8573
# Epoch 92/100
# 125/125 [==============================] - 4s 35ms/step - loss: 0.0490 - accuracy: 0.9853 - val_loss: 0.8331 - val_accuracy: 0.8575
# Epoch 93/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.0487 - accuracy: 0.9852 - val_loss: 0.8393 - val_accuracy: 0.8569
# Epoch 94/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.0480 - accuracy: 0.9854 - val_loss: 0.8382 - val_accuracy: 0.8588
# Epoch 95/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0466 - accuracy: 0.9858 - val_loss: 0.8488 - val_accuracy: 0.8575
# Epoch 96/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.0459 - accuracy: 0.9860 - val_loss: 0.8441 - val_accuracy: 0.8583
# Epoch 97/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.0442 - accuracy: 0.9865 - val_loss: 0.8562 - val_accuracy: 0.8578
# Epoch 98/100
# 125/125 [==============================] - 4s 34ms/step - loss: 0.0435 - accuracy: 0.9868 - val_loss: 0.8635 - val_accuracy: 0.8567
# Epoch 99/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0436 - accuracy: 0.9867 - val_loss: 0.8652 - val_accuracy: 0.8581
# Epoch 100/100
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0427 - accuracy: 0.9869 - val_loss: 0.8726 - val_accuracy: 0.8567

# %%
# Save model
model.save("e2d")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: e2d/assets
# INFO:tensorflow:Assets written to: e2d/assets

# %%
model = keras.models.load_model("e2d")

encoder_inputs = model.input[0]  # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=(latent_dim,))
decoder_state_input_c = keras.Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %%
for seq_index in range(20):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# -
# Input sentence: Go.
# Decoded sentence: Lopen!
#
# -
# Input sentence: Go.
# Decoded sentence: Lopen!
#
# -
# Input sentence: Hi.
# Decoded sentence: Hai!
#
# -
# Input sentence: Hi.
# Decoded sentence: Hai!
#
# -
# Input sentence: Hi.
# Decoded sentence: Hai!
#
# -
# Input sentence: Run!
# Decoded sentence: Ren!
#
# -
# Input sentence: Run!
# Decoded sentence: Ren!
#
# -
# Input sentence: Run.
# Decoded sentence: Ren!
#
# -
# Input sentence: Run.
# Decoded sentence: Ren!
#
# -
# Input sentence: Who?
# Decoded sentence: Wie?
#
# -
# Input sentence: Wow!
# Decoded sentence: Da's niet gek!
#
# -
# Input sentence: Duck!
# Decoded sentence: Eend!
#
# -
# Input sentence: Fire!
# Decoded sentence: Vuur!
#
# -
# Input sentence: Fire!
# Decoded sentence: Vuur!
#
# -
# Input sentence: Help!
# Decoded sentence: Help!
#
# -
# Input sentence: Jump.
# Decoded sentence: Spring.
#
# -
# Input sentence: Stop!
# Decoded sentence: Hou daarmee op!
#
# -
# Input sentence: Stop!
# Decoded sentence: Hou daarmee op!
#
# -
# Input sentence: Stop!
# Decoded sentence: Hou daarmee op!
#
# -
# Input sentence: Stop!
# Decoded sentence: Hou daarmee op!
